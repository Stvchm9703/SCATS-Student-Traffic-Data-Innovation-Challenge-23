# Name: duration, dtype: int64, description: Time in seconds data was collected.
#
# Name: gapTime, dtype: int64, description: The time difference in seconds between the rear of a vehicle and the front of its follower.
#
# Name: greenTime, dtype: int64, description: The time interval between when the message to begin data collection is sent to the controller, to the time at which the collected data is received from the controller.
#
# Name: lddId, dtype: int64, description: Unique ID for Inductive loop detector record.
#
# Name: nonOccupancy, dtype: int64, description:  the total time the loop did not have a vehicle on it during this collection period.
#
# Name: phases, dtype: object, description: phase ID list
#
# Name: rawDS, dtype: int64, description: Raw Degree of Saturation. the degree of saturation a utilisation metric based on comparing the wasted extra gap between vehicles compared to the optimal gap between vehicles. It is raw because it is based purely on a single collection not on all the collections in a cycle. It is not the value that is used for cyclic based traffic algorithms (A signal can run multiple times in a cycle).
#
# Name: rawDSVk, dtype: int64, description: Raw Reconstituted Volume. rawDSVK is the number of vehicles that would have used the green time if they had similar occupancies (a factor of speed and length) to vehicles that were measured during the optimal gap between vehicles. This is a way of not penalising slow or long vehicles. It is raw because it is based purely on a single collection not on all the collections in a cycle. It is not the value that is used for cyclic based traffic algorithms (A signal can run multiple times in a cycle).
#
# Name: recTimeRef, dtype: int64, description: it is the time that the message is received from the controller.
#
# Name: redTime, dtype: int64description: Seconds incremented by SCATS, between a VOC reply being received and the next BVO request being sent. It represents the time when the detector data was not collected. Only included if this is phase or signal based collection. redTime in simulation is number of seconds between greens. Traffic lights change colour.
#
# Name: regionId, dtype: int64, description: Unique region id such as RYDE.
#
# Name: signalGroup, dtype: int64, description: The signal group number is included, if data is configured to be collected when the signal group runs.
#
# Name: siteUId, dtype: int64, description: Unique site Uid which hash code makeup of Jurisdiction + Region + Site Id.
#
# Name: startOffsetTime, dtype: int64, description: Offset in seconds from the record creation timestamp when request to collect data was sent.
#
# Name: timeInterval, dtype: int64, description: The time interval is included, if data is configured to be collected as a time interval, e.g. every 20 seconds.
#
# Name: type, dtype: int64, description: 0 – phase; 1 – signal group; 2 – timed interval.
#
# Name: volume, dtype: int64, description: Traffic volume. Volume is a measure of number of vehicles. Measured in vehicles per hour (vph). BVO (Begin Volume and Occupancy) and VOC (Volume and Occupancy)
#
#
# <!-- Raw DS is the degree of saturation a utilisation metric based on comparing the wasted extra gap between vehicles compared to the optimal gap between vehicles. It is raw because it is based purely on a single collection not on all the collections in a cycle. It is not the value that is used for cyclic based traffic algorithms (A signal can run multiple times in a cycle). -->
#
# <!-- rawDSVK is the number of vehicles that would have used the green time if they had similar occupancies (a factor of speed and length) to vehicles that were measured during the optimal gap between vehicles. This is a way of not penalising slow or long vehicles. It is raw because it is based purely on a single collection not on all the collections in a cycle. It is not the value that is used for cyclic based traffic algorithms (A signal can run multiple times in a cycle). -->
#
# <!-- redTime in simulation is number of seconds between greens. Traffic lights change colour. -->
# <!--
# Volume is a measure of number of vehicles. Measured in vehicles per hour (vph). BVO (Begin Volume and Occupancy) and VOC (Volume and Occupancy) -->

# %%
raw_df.info()
raw_df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3749039 entries, 0 to 3749038
# Data columns (total 21 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   date             object
#  1   dateId           int64
#  2   detNo            int64
#  3   detState         int64
#  4   duration         int64
#  5   gapTime          int64
#  6   greenTime        int64
#  7   lddId            int64
#  8   nonOccupancy     int64
#  9   phases           object
#  10  rawDS            int64
#  11  rawDSVk          int64
#  12  recTimeRef       int64
#  13  redTime          int64
#  14  regionId         int64
#  15  signalGroup      int64
#  16  siteUId          int64
#  17  startOffsetTime  int64
#  18  timeInterval     int64
#  19  type             int64
#  20  volume           int64
# dtypes: int64(19), object(2)
# memory usage: 600.7+ MB
#         date  dateId  detNo  detState  duration  gapTime  greenTime  \
# ...

# %%
for col in raw_df.columns:
    print("#", col)
    print(raw_df[col].value_counts())
    print("------------------")
# Out:
# # date
# date
# 20230402    26987
# 20230407    26969
# 20230409    26963
# 20230425    26936
# 20230430    26681
#             ...
# 20230527    23458
# 20230216    22638
# 20230525    22571
# 20230210    21618
# 20230526    21310
# Name: count, Length: 151, dtype: int64
# ------------------
# # dateId
# dateId
# 19454    26805
# 19456    26770
# 19472    26614
# 19359    26321
# 19358    26120
#          ...
# 19404    22638
# 19502    22514
# 19398    21618
# 19503    21438
# 19509     1097
# Name: count, Length: 152, dtype: int64
# ------------------
# # detNo
# detNo
# 6     678714
# 7     678713
# 2     573767
# 3     573767
# 5     394995
# 1     389171
# 9     130726
# 10    130726
# 11     99230
# 12     99230
# Name: count, dtype: int64
# ------------------
# # detState
# detState
# 3    3491360
# 2     196759
# 0      60858
# 1         62
# Name: count, dtype: int64
# ------------------
# # duration
# duration
# 38     484097
# 37     270990
# 13     133936
# ...

# %%
temp_df = raw_df.copy()
# remove column
temp_df.drop(["phases"], axis=1, inplace=True)

# %%
corr_heatmap(temp_df)

# %% [markdown]
# # Step-1 : data preprocess , transform and cleaning
#
# - recTimeRef : UnixTime (which is include Date and time)
#
#   - convert to grouped
#     - time-to-timeFrame : (6-10),(10-14),(14-18), (18-22), (22-2) , (2-6)
#     - weekday : (Mon), (Tue), (Wed), (Thu), (Fri), (Sat), (Sun)
#     - holiday : (0) , (1)
#     - month
#   - drop: date, dateId
#
# - drop less-relevent
#
#   - drop >= 0.25
#
# - timeInterval
#
#   - boolean value?
#
# - regionId
#
#   - all should same (NSW)
#
# - type
#
#   - all should same (traffic light)
#
# - drop lddid

# %%
temp_df1 = (
    raw_df.copy()
    .drop(
        ["regionId", "signalGroup", "timeInterval", "type", "lddId", "date", "dateId"],
        axis=1,
    )
    .dropna(axis=0, how="all")
)

temp_df1["recTimeRef"] = pd.to_datetime(temp_df1["recTimeRef"], unit="s")

# %%
temp_df1["recTimeRef__month"] = temp_df1["recTimeRef"].dt.month


# time-to-timeFrame : (6-10),(10-14),(14-18), (18-22), (22-2) , (2-6)
def convTimeSession(x):
    if x.time() >= datetime.time(6) and x.time() < datetime.time(10):
        return 1  #'0600-1000'
        # return '0600-1000'
    elif x.time() >= datetime.time(10) and x.time() < datetime.time(14):
        return 2  #'1000-1400'
        # return '1000-1400'
    elif x.time() >= datetime.time(14) and x.time() < datetime.time(18):
        return 3  #'1400-1800'
        # return '1400-1800'
    elif x.time() >= datetime.time(18) and x.time() < datetime.time(22):
        return 4  #'1800-2200'
        # return '1800-2200'
    elif x.time() >= datetime.time(22) or x.time() < datetime.time(2):
        return 5  #'2200-0200'
        # return '2200-0200'
    elif x.time() >= datetime.time(2) and x.time() < datetime.time(6):
        return 6  #'0200-0600'
        # return '0200-0600'


temp_df1["recTimeRef__timeSession"] = temp_df1["recTimeRef"].apply(convTimeSession)
temp_df1["recTimeRef__timeSession"] = temp_df1["recTimeRef__timeSession"].astype(
    "category"
)
temp_df1["recTimeRef__weekday"] = temp_df1["recTimeRef"].dt.day_of_week

# %%
from datetime import date
import holidays

holidays_set = holidays.country_holidays("AU", subdiv="NSW")

temp_df1["recTimeRef__isHolidays"] = temp_df1["recTimeRef"].apply(
    lambda x: x in holidays_set
)

# %%
# temp_df1["phases"] = temp_df1["phases"].apply(lambda x: (x.split(" ")))

temp_df1["phases__has1"] = temp_df1["phases"].apply(lambda x: int("1" in x))
temp_df1["phases__has2"] = temp_df1["phases"].apply(lambda x: int("2" in x))
temp_df1["phases__has3"] = temp_df1["phases"].apply(lambda x: int("3" in x))
temp_df1["phases__has4"] = temp_df1["phases"].apply(lambda x: int("4" in x))
temp_df1.drop(["phases"], axis=1, inplace=True)

# %%
# simply site uid to 1,2,3,4
def siteUidConv(x):
    # 1536389048
    # 1712128823
    # 383241760
    # 383244672
    if x == 1536389048:
        return 1
    elif x == 1712128823:
        return 2
    elif x == 383241760:
        return 3
    elif x == 383244672:
        return 4


temp_df1["siteUId"] = temp_df1["siteUId"].apply(siteUidConv).astype("category")

# %%
print(temp_df1.dtypes)
# Out:
# detNo                               int64
# detState                            int64
# duration                            int64
# gapTime                             int64
# greenTime                           int64
# nonOccupancy                        int64
# rawDS                               int64
# rawDSVk                             int64
# recTimeRef                 datetime64[ns]
# redTime                             int64
# siteUId                          category
# startOffsetTime                     int64
# volume                              int64
# recTimeRef__month                   int32
# recTimeRef__timeSession          category
# recTimeRef__weekday                 int32
# recTimeRef__isHolidays               bool
# phases__has1                        int64
# phases__has2                        int64
# phases__has3                        int64
# phases__has4                        int64
# dtype: object

# %%
temp_df1.drop(["recTimeRef"], axis=1, inplace=True)

# %%
# grap the corr > 0.2 cols


corr_info = temp_df1.corr().abs().dropna(axis=0, how="all")
corr_info
# Out:
#                             detNo  detState  duration   gapTime  greenTime  \
# detNo                    1.000000  0.011605  0.229021  0.051736   0.168724
# detState                 0.011605  1.000000  0.187325  0.073794   0.171331
# duration                 0.229021  0.187325  1.000000  0.068626   0.529948
# gapTime                  0.051736  0.073794  0.068626  1.000000   0.103801
# greenTime                0.168724  0.171331  0.529948  0.103801   1.000000
# nonOccupancy             0.226088  0.377054  0.831762  0.031049   0.388522
# rawDS                    0.062593  0.228721  0.074817  0.056406   0.337653
# rawDSVk                  0.061725  0.248867  0.510344  0.077024   0.373691
# redTime                  0.166701  0.060632  0.107892  0.000164   0.082351
# siteUId                  0.440512  0.100979  0.235931  0.076533   0.266447
# startOffsetTime          0.038735  0.017309  0.084988  0.009417   0.106367
# ...

# %%
corr_heatmap(temp_df1)

# %%
# should_remove = corr_info.columns.to_list().copy()

# for col in corr_info.columns:
#     print("-------------------")
#     for row in corr_info.index:
#         if corr_info[col][row] >= 0.225 and col != row:
#             print(col, row)
#             if col in should_remove:
#                 should_remove.remove(col)
#             if row in should_remove:
#                 should_remove.remove(row)

# print(should_remove)
# # count = corr_info[corr_info[col] < 0.2].count()
# # count

# %%
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()


for col in corr_info.columns:
    # print("-------------------")
    for row in corr_info.index:
        if corr_info[col][row] >= 0.225 and col != row:
            if G.get_edge_data(col, row, default=0) == 0:
                G.add_edge(col, row, weight=round(corr_info[col][row], 3))


# elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] >= 0.2]
elarge = G.edges(data=True)
# esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d["weight"] < 0.2]

# pos = nx.spring_layout(G, seed=7 )  # positions for all nodes - seed for reproducibility

# # nodes
# nx.draw_networkx_nodes(G, pos, node_size=70)

# # edges
# nx.draw_networkx_edges(G, pos, edgelist=elarge, width=2)
# # nx.draw_networkx_edges(
# #     G, pos, edgelist=esmall, width=2, alpha=0.5, edge_color="b", style="dashed"
# # )

# # node labels
# nx.draw_networkx_labels(G, pos, font_size=10, font_family="sans-serif")
# # edge weight labels
# edge_labels = nx.get_edge_attributes(G, "weight")
# nx.draw_networkx_edge_labels(G, pos, edge_labels, font_size=6)

# ax = plt.gca()
# ax.margins(0.08)
# plt.axis("off")

# # plt.tight_layout()
# # plt.size(720, 720/3*2)
# plt.figure(figsize=(720, 720/3*2))
# plt.show()

# %%
G.size()
# Out:
# 37

# %%
list(G.nodes)
# Out:
# ['detNo',
#  'duration',
#  'nonOccupancy',
#  'siteUId',
#  'phases__has1',
#  'phases__has2',
#  'phases__has3',
#  'phases__has4',
#  'detState',
#  'rawDS',
#  'rawDSVk',
#  'greenTime',
#  'volume',
#  'redTime']

# %%
# for _node in list(G.nodes):
#     _edge = list(G.edges(_node, data=True))
#     print(_node, _edge)


weight_ordered = list(G.edges(data=True))
weight_ordered = sorted(weight_ordered, key=lambda x: x[2]["weight"], reverse=True)
weight_ordered
# Out:
# [('phases__has2', 'phases__has4', {'weight': 1.0}),
#  ('duration', 'nonOccupancy', {'weight': 0.832}),
#  ('phases__has1', 'phases__has3', {'weight': 0.789}),
#  ('rawDS', 'rawDSVk', {'weight': 0.747}),
#  ('detNo', 'phases__has3', {'weight': 0.682}),
#  ('duration', 'volume', {'weight': 0.617}),
#  ('detNo', 'phases__has2', {'weight': 0.581}),
#  ('detNo', 'phases__has4', {'weight': 0.581}),
#  ('detNo', 'phases__has1', {'weight': 0.58}),
#  ('duration', 'greenTime', {'weight': 0.53}),
#  ('duration', 'rawDSVk', {'weight': 0.51}),
#  ('rawDSVk', 'volume', {'weight': 0.491}),
#  ('phases__has1', 'greenTime', {'weight': 0.477}),
#  ('nonOccupancy', 'volume', {'weight': 0.462}),
#  ('greenTime', 'volume', {'weight': 0.443}),
#  ('detNo', 'siteUId', {'weight': 0.441}),
#  ('siteUId', 'phases__has1', {'weight': 0.422}),
#  ('duration', 'phases__has1', {'weight': 0.397}),
#  ('nonOccupancy', 'greenTime', {'weight': 0.389}),
#  ('nonOccupancy', 'rawDS', {'weight': 0.382}),
# ...

# %%
# Out:
# EdgeView([('detNo', 'duration'), ('detNo', 'nonOccupancy'), ('detNo', 'siteUId'), ('detNo', 'phases__has1'), ('detNo', 'phases__has2'), ('detNo', 'phases__has3'), ('detNo', 'phases__has4'), ('duration', 'greenTime'), ('duration', 'nonOccupancy'), ('duration', 'rawDSVk'), ('duration', 'siteUId'), ('duration', 'volume'), ('duration', 'phases__has1'), ('duration', 'phases__has3'), ('nonOccupancy', 'detState'), ('nonOccupancy', 'greenTime'), ('nonOccupancy', 'rawDS'), ('nonOccupancy', 'volume'), ('nonOccupancy', 'phases__has1'), ('siteUId', 'greenTime'), ('siteUId', 'phases__has1'), ('siteUId', 'phases__has3'), ('phases__has1', 'greenTime'), ('phases__has1', 'phases__has3'), ('phases__has2', 'rawDS'), ('phases__has2', 'phases__has4'), ('phases__has3', 'greenTime'), ('phases__has3', 'redTime'), ('phases__has4', 'rawDS'), ('detState', 'rawDS'), ('detState', 'rawDSVk'), ('rawDS', 'greenTime'), ('rawDS', 'rawDSVk'), ('rawDS', 'volume'), ('rawDSVk', 'greenTime'), ('rawDSVk', 'volume'), ('gree
# ...

# %%
temp_df1= temp_df1[list(G.nodes)]

# %%
corr_heatmap(temp_df1)

# %%
# do the snap shot
temp_df1.to_parquet("../data/pretrain-snapshot.snappy.parquet", engine='pyarrow' , compression='snappy')

# %%
# resume
import pandas
temp_df1 = pandas.read_parquet("../data/pretrain-snapshot.snappy.parquet")

# %%
# model training
# import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# here to roughly split the data


def generate_train_test_set(x_col, y_col, new_edited_trainset, random_state=0):
    X_train, X_test, y_train, y_test = train_test_split(
        new_edited_trainset[x_col],
        new_edited_trainset[y_col],
        test_size=0.3,
        random_state=random_state,
    )
    return [X_train, X_test, y_train, y_test]


target_result = ["duration"]
params = temp_df1.columns.to_list()
params = [x for x in params if x not in target_result]

[X_train, X_test, y_train, y_test] = generate_train_test_set(
    x_col=params,
    y_col=target_result,
    new_edited_trainset=temp_df1,
    random_state=7,
)

# %%
import numpy
from sklearn.metrics import confusion_matrix
import seaborn

def model_result_rend(modeL_name, y_test, y_pred_lr, auc, fpr, tpr):
    plt.figure()
    group_names = ['True Neg', 'False Neg', 'False pos', 'True Pos']
    group_counts = ["{0:0.0f}".format( value) for value in confusion_matrix(y_test, y_pred_lr) .flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in confusion_matrix(y_test, y_pred_lr).flatten()/numpy.sum(confusion_matrix(y_test, y_pred_lr))]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip( group_names, group_counts, group_percentages)]
    labels = numpy.asarray(labels).reshape(2, 2)
    seaborn.heatmap(confusion_matrix(y_test, y_pred_lr), annot=labels, fmt='', cmap='Blues')
    plt.title("{modeL_name} result".format(modeL_name=modeL_name))
    plt.xlabel("Actual")
    plt.ylabel("Predicted")
    plt.show()

    plt.figure()
    lw = 2  # the line width
    plt.plot(fpr, tpr, color='darkorange',
            lw=lw, label='ROC curve (area = %0.2f)' % auc)
    # The dashed line for random choice
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")

    plt.show()

# %%
import joblib
import pandas
import time

from sklearn.metrics import classification_report, roc_auc_score, roc_curve

def model_randomForstClassifier(X_train: pandas.DataFrame, X_test: pandas.DataFrame, y_train: pandas.DataFrame, y_test: pandas.DataFrame):
    timer = time.perf_counter()
    clf = RandomForestClassifier(
        n_estimators=100,
        oob_score=True
    )
    clf.fit(X_train, y_train)
    _score = clf.score(X_test, y_test)
    y_probs = clf.predict_proba(X_test)
    print(y_probs)
    # y_probs_list = [ int(b > a) for ([a, b]) in y_probs ]
    y_probs_list =  y_probs 
    roc = roc_auc_score(
        y_test[y_test.columns[0]].to_list(),
        y_probs_list,
        multi_class="ovr", average="weighted")
    fpr, tpr, thresholds = roc_curve(y_test[y_test.columns[0]].to_list(), y_probs_list, pos_label=1)
    
    print(classification_report( y_test[y_test.columns[0]].to_list(), y_probs_list))

    # roc_list.append(_score)
    print("score in test-set for {model}: {_score}, roc: {roc} ".format(
        model=clf.__class__.__name__, _score=_score, roc=roc))
    new_timer = time.perf_counter()
    time_diff = (new_timer - timer)
    model_result_rend(modeL_name=clf.__class__.__name__, y_test=y_test,
                      y_pred_lr=y_probs_list, auc=roc, fpr=fpr, tpr=tpr)


    joblib.dump(clf, './data/model_{model_name}_{start_time}.pkl'.format(model_name=clf.__class__.__name__, start_time=timer))
    return {
        # 'model': clf,
        'model_name': clf.__class__.__name__,
        'score': _score,
        'roc_auc': roc,
        'complete_time': time_diff,
        'start_time': timer,
        'end_time': new_timer,
    }

# %%
from sklearn.neural_network import MLPClassifier


# Method 3 : MLP Classifier
def model_mlp_classifier(X_train: pandas.DataFrame, X_test: pandas.DataFrame, y_train: pandas.DataFrame, y_test: pandas.DataFrame):
    timer = time.perf_counter()
    clf = MLPClassifier(
        hidden_layer_sizes=(18, 10, 6, 2),
        max_iter=15000)
    # print('inited model, start fitting')
    clf.fit(X_train, y_train['satisfaction'].to_list())
    # print('fitted, start score')

    _score = clf.score(X_test, y_test)

    # Get the probabilities of each class.
    y_probs = clf.predict_proba(X_test)
    # y_probs_list = [
    #     int(b > a) for ([a, b]) in y_probs
    # ]
    y_probs_list = y_probs
    roc = roc_auc_score(
        y_test[y_test.columns[0]].to_list(),
        y_probs_list,
        multi_class="ovr", average="weighted")
    fpr, tpr, thresholds = roc_curve(y_test, y_probs_list, pos_label=1)
    # roc_list.append(_score)
    print(classification_report(
        y_test[y_test.columns[0]].to_list(), y_probs_list))
    print("score in test-set for {model}: {_score}, roc: {roc} ".format(
        model=clf.__class__.__name__, _score=_score, roc=roc))
    new_timer = time.perf_counter()
    time_diff = (new_timer - timer)
    model_result_rend(modeL_name=clf.__class__.__name__, y_test=y_test,
                      y_pred_lr=y_probs_list, auc=roc, fpr=fpr, tpr=tpr)

    joblib.dump(clf, './data/model_{model_name}_{start_time}.pkl'.format(
        model_name=clf.__class__.__name__, start_time=timer))
    return {
        # 'model': clf,
        'model_name': clf.__class__.__name__,
        'score': _score,
        'roc_auc': roc,
        'complete_time': time_diff,
        'start_time': timer,
        'end_time': new_timer,
    }

# %%
model_randomForstClassifier(X_train, X_test, y_train, y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
